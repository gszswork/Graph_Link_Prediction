# %% [markdown]
# # Pre-setting if using Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Graph_Link_Prediction/biggraph/
# Out:
# /content/drive/MyDrive/Graph_Link_Prediction/biggraph

# %% [markdown]
# # Training

# %%
! pip install torchbiggraph

# %%
#!/usr/bin/env python3

# Copyright (c) Facebook, Inc. and its affiliates.
# All rights reserved.
#
# This source code is licensed under the BSD-style license found in the
# LICENSE.txt file in the root directory of this source tree.

import argparse
import random
from itertools import chain
from pathlib import Path

import attr
import pkg_resources

from torchbiggraph.config import add_to_sys_path, ConfigFileLoader
from torchbiggraph.converters.import_from_tsv import convert_input_data
from torchbiggraph.converters.utils import download_url, extract_gzip
from torchbiggraph.eval import do_eval
from torchbiggraph.train import train
from torchbiggraph.util import (
    set_logging_verbosity,
    setup_logging,
    SubprocessInitializer,
)


TRAIN_FILENAME = "train.txt"
TEST_FILENAME = "test.txt"
FILENAMES = [
    TRAIN_FILENAME,
    TEST_FILENAME,
]
TRAIN_FRACTION = 0.75

# Figure out the path where the sample config was installed by the package manager.
# This can be overridden with --config.
DEFAULT_CONFIG = '/content/drive/MyDrive/Graph_Link_Prediction/biggraph/config/config_50_epochs_ranking.py'


def random_split_file(fpath: Path) -> None:
    train_file = fpath.parent / TRAIN_FILENAME
    test_file = fpath.parent / TEST_FILENAME

    if train_file.exists() and test_file.exists():
        print("Found some files that indicate that the input data "
              "has already been shuffled and split, not doing it again.")
        print(f"These files are: {train_file} and {test_file}")
        return

    print('Shuffling and splitting train/test file. This may take a while.')

    print(f"Reading data from file: {fpath}")
    with fpath.open("rt") as in_tf:
        lines = in_tf.readlines()

    # The first few lines are comments
    #lines = lines[4:]
    print('Shuffling data')
    random.shuffle(lines)
    split_len = int(len(lines) * TRAIN_FRACTION)

    print('Splitting to train and test files')
    with train_file.open("wt") as out_tf_train:
        for line in lines[:split_len]:
            out_tf_train.write(line)

    with test_file.open("wt") as out_tf_test:
        for line in lines[split_len:]:
            out_tf_test.write(line)


def main():
    setup_logging()



    # download data
    path = './data/statml/'
    data_dir = Path(path)
    
    training_data = './data/statml/edges_no_duplicate.txt'
    fpath = Path(training_data)

    # random split file for train and test
    random_split_file(fpath)

    loader = ConfigFileLoader()
    config = loader.load_config(DEFAULT_CONFIG, overrides=None)
    set_logging_verbosity(config.verbose)
    subprocess_init = SubprocessInitializer()
    subprocess_init.register(setup_logging, config.verbose)
    subprocess_init.register(add_to_sys_path, loader.config_dir.name)
    input_edge_paths = [data_dir / name for name in FILENAMES]
    output_train_path, output_test_path = config.edge_paths

    convert_input_data(
        config.entities,
        config.relations,
        config.entity_path,
        config.edge_paths,
        input_edge_paths,
        lhs_col=0,
        rhs_col=1,
        rel_col=None,
        dynamic_relations=config.dynamic_relations,
    )

    train_config = attr.evolve(config, edge_paths=[output_train_path])
    train(train_config, subprocess_init=subprocess_init)

    eval_config = attr.evolve(config, edge_paths=[output_test_path])
    do_eval(eval_config, subprocess_init=subprocess_init)


if __name__ == "__main__":
    main()
# Out:
# Shuffling and splitting train/test file. This may take a while.
# Reading data from file: data/statml/edges_no_duplicate.txt
# Shuffling data
# Splitting to train and test files
# Using the 1 relation types given in the config
# Searching for the entities in the edge files...
# Entity type user_id:
# - Found 3767 entities
# - Removing the ones with fewer than 1 occurrences...
# - Left with 3767 entities
# - Shuffling them...
# Preparing counts and dictionaries for entities and relation types:
# - Writing count of entity type user_id and partition 0
# Preparing edge path data/train_partitioned, out of the edges found in data/statml/train.txt
# - Edges will be partitioned in 1 x 1 buckets.
# - Processed 24052 edges in total
# Preparing edge path data/test_partitioned, out of the edges found in data/statml/test.txt
# - Edges will be partitioned in 1 x 1 buckets.
# - Processed 8018 edges in total
# 2021-04-07 06:37:17,139   [Trainer-0] Loading entity counts...
# 2021-04-07 06:37:17,148   [Trainer-0] Creating workers...
# 2021-04-07 06:37:17,256   [Trainer-0] Initializing global model...
# 2021-04-07 06:37:17,297   [Trainer-0] Starting epoch 1 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:17,305   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:17,311   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:17,316   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:17,322   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:21,393   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 4.05 s ( 0.0059 M/sec ); io: 0.03 s ( 21.57 MB/sec )
# 2021-04-07 06:37:21,395   [Trainer-0] ( 0 , 0 ): loss:  8.74536 , violators_lhs:  18.2343 , violators_rhs:  18.2674 , count:  24052
# 2021-04-07 06:37:21,400   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:21,403   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:21,405   [Trainer-0] Finished epoch 1 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:21,426   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:21,441   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:21,450   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:21,452   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:21,462   [Trainer-0] Starting epoch 2 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:21,465   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:21,468   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:21,470   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:21,472   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:21,889   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.40 s ( 0.06 M/sec ); io: 0.02 s ( 35.25 MB/sec )
# 2021-04-07 06:37:21,890   [Trainer-0] ( 0 , 0 ): loss:  0.608391 , violators_lhs:  1.08344 , violators_rhs:  1.08161 , count:  24052
# 2021-04-07 06:37:21,892   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:21,893   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:21,895   [Trainer-0] Finished epoch 2 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:21,921   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:21,932   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:21,942   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:21,944   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:21,960   [Trainer-0] Starting epoch 3 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:21,962   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:21,963   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:21,965   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:21,967   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:22,388   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.41 s ( 0.059 M/sec ); io: 0.01 s ( 43.92 MB/sec )
# 2021-04-07 06:37:22,390   [Trainer-0] ( 0 , 0 ): loss:  0.535754 , violators_lhs:  0.977174 , violators_rhs:  0.972767 , count:  24052
# 2021-04-07 06:37:22,395   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:22,397   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:22,398   [Trainer-0] Finished epoch 3 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:22,419   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:22,441   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:22,447   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:22,449   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:22,462   [Trainer-0] Starting epoch 4 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:22,467   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:22,470   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:22,472   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:22,473   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:22,917   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.43 s ( 0.056 M/sec ); io: 0.02 s ( 36.31 MB/sec )
# 2021-04-07 06:37:22,919   [Trainer-0] ( 0 , 0 ): loss:  0.512648 , violators_lhs:  0.944745 , violators_rhs:  0.953684 , count:  24052
# 2021-04-07 06:37:22,922   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:22,925   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:22,928   [Trainer-0] Finished epoch 4 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:22,948   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:22,966   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:22,974   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:22,976   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:22,992   [Trainer-0] Starting epoch 5 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:22,996   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:22,998   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:23,003   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:23,005   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:23,427   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.41 s ( 0.059 M/sec ); io: 0.01 s ( 41.06 MB/sec )
# 2021-04-07 06:37:23,428   [Trainer-0] ( 0 , 0 ): loss:  0.489924 , violators_lhs:  0.90637 , violators_rhs:  0.912024 , count:  24052
# 2021-04-07 06:37:23,438   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:23,440   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:23,442   [Trainer-0] Finished epoch 5 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:23,592   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:23,608   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:23,620   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:23,622   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:23,641   [Trainer-0] Starting epoch 6 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:23,645   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:23,646   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:23,648   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:23,651   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:24,209   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.54 s ( 0.044 M/sec ); io: 0.02 s ( 31.12 MB/sec )
# 2021-04-07 06:37:24,216   [Trainer-0] ( 0 , 0 ): loss:  0.47299 , violators_lhs:  0.877973 , violators_rhs:  0.887535 , count:  24052
# 2021-04-07 06:37:24,219   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:24,226   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:24,230   [Trainer-0] Finished epoch 6 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:24,277   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:24,307   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:24,319   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:24,324   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:24,353   [Trainer-0] Starting epoch 7 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:24,357   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:24,363   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:24,365   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:24,368   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:25,212   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.82 s ( 0.029 M/sec ); io: 0.03 s ( 18.87 MB/sec )
# 2021-04-07 06:37:25,215   [Trainer-0] ( 0 , 0 ): loss:  0.463332 , violators_lhs:  0.867163 , violators_rhs:  0.867204 , count:  24052
# 2021-04-07 06:37:25,219   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:25,220   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:25,222   [Trainer-0] Finished epoch 7 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:25,255   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:25,274   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:25,284   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:25,287   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:25,314   [Trainer-0] Starting epoch 8 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:25,323   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:25,325   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:25,327   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:25,331   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:26,044   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.68 s ( 0.035 M/sec ); io: 0.04 s ( 16.43 MB/sec )
# 2021-04-07 06:37:26,046   [Trainer-0] ( 0 , 0 ): loss:  0.458493 , violators_lhs:  0.863296 , violators_rhs:  0.857642 , count:  24052
# 2021-04-07 06:37:26,049   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:26,054   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:26,059   [Trainer-0] Finished epoch 8 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:26,097   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:26,128   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:26,141   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:26,145   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:26,166   [Trainer-0] Starting epoch 9 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:26,170   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:26,172   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:26,174   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:26,176   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:26,843   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.64 s ( 0.038 M/sec ); io: 0.03 s ( 17.01 MB/sec )
# 2021-04-07 06:37:26,846   [Trainer-0] ( 0 , 0 ): loss:  0.452007 , violators_lhs:  0.851197 , violators_rhs:  0.852985 , count:  24052
# 2021-04-07 06:37:26,847   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:26,850   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:26,852   [Trainer-0] Finished epoch 9 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:26,876   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:26,893   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:27,038   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:27,040   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:27,076   [Trainer-0] Starting epoch 10 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:27,083   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:27,085   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:27,087   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:27,091   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:27,556   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.44 s ( 0.054 M/sec ); io: 0.03 s ( 22.97 MB/sec )
# 2021-04-07 06:37:27,558   [Trainer-0] ( 0 , 0 ): loss:  0.440662 , violators_lhs:  0.833361 , violators_rhs:  0.826875 , count:  24052
# 2021-04-07 06:37:27,560   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:27,561   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:27,563   [Trainer-0] Finished epoch 10 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:27,593   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:27,604   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:27,613   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:27,615   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:27,630   [Trainer-0] Starting epoch 11 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:27,632   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:27,634   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:27,637   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:27,638   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:28,075   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.42 s ( 0.057 M/sec ); io: 0.01 s ( 40.54 MB/sec )
# 2021-04-07 06:37:28,077   [Trainer-0] ( 0 , 0 ): loss:  0.443785 , violators_lhs:  0.823466 , violators_rhs:  0.832779 , count:  24052
# 2021-04-07 06:37:28,081   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:28,083   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:28,084   [Trainer-0] Finished epoch 11 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:28,109   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:28,122   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:28,148   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:28,149   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:28,168   [Trainer-0] Starting epoch 12 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:28,172   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:28,176   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:28,179   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:28,181   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:28,600   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.40 s ( 0.059 M/sec ); io: 0.02 s ( 35.78 MB/sec )
# 2021-04-07 06:37:28,602   [Trainer-0] ( 0 , 0 ): loss:  0.438638 , violators_lhs:  0.828871 , violators_rhs:  0.817271 , count:  24052
# 2021-04-07 06:37:28,603   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:28,605   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:28,606   [Trainer-0] Finished epoch 12 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:28,639   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:28,653   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:28,667   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:28,672   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:28,690   [Trainer-0] Starting epoch 13 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:28,697   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:28,698   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:28,702   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:28,707   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:29,154   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.43 s ( 0.056 M/sec ); io: 0.02 s ( 25.88 MB/sec )
# 2021-04-07 06:37:29,156   [Trainer-0] ( 0 , 0 ): loss:  0.434779 , violators_lhs:  0.813737 , violators_rhs:  0.823507 , count:  24052
# 2021-04-07 06:37:29,159   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:29,162   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:29,164   [Trainer-0] Finished epoch 13 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:29,195   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:29,213   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:29,221   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:29,223   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:29,389   [Trainer-0] Starting epoch 14 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:29,397   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:29,403   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:29,404   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:29,409   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:29,831   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.41 s ( 0.059 M/sec ); io: 0.02 s ( 28.72 MB/sec )
# 2021-04-07 06:37:29,836   [Trainer-0] ( 0 , 0 ): loss:  0.428659 , violators_lhs:  0.799144 , violators_rhs:  0.806794 , count:  24052
# 2021-04-07 06:37:29,838   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:29,839   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:29,840   [Trainer-0] Finished epoch 14 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:29,867   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:29,883   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:29,894   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:29,896   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:29,917   [Trainer-0] Starting epoch 15 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:29,923   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:29,927   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:29,930   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:29,937   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:30,362   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.41 s ( 0.058 M/sec ); io: 0.02 s ( 29.84 MB/sec )
# 2021-04-07 06:37:30,363   [Trainer-0] ( 0 , 0 ): loss:  0.430089 , violators_lhs:  0.809247 , violators_rhs:  0.81303 , count:  24052
# 2021-04-07 06:37:30,365   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:30,367   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:30,368   [Trainer-0] Finished epoch 15 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:30,393   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:30,405   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:30,416   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:30,418   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:30,434   [Trainer-0] Starting epoch 16 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:30,440   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:30,441   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:30,445   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:30,447   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:30,892   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.43 s ( 0.056 M/sec ); io: 0.02 s ( 33.64 MB/sec )
# 2021-04-07 06:37:30,894   [Trainer-0] ( 0 , 0 ): loss:  0.426943 , violators_lhs:  0.808415 , violators_rhs:  0.804756 , count:  24052
# 2021-04-07 06:37:30,895   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:30,898   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:30,900   [Trainer-0] Finished epoch 16 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:30,926   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:30,939   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:30,950   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:30,952   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:30,970   [Trainer-0] Starting epoch 17 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:30,973   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:30,977   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:30,979   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:30,981   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:31,420   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.43 s ( 0.056 M/sec ); io: 0.01 s ( 38.92 MB/sec )
# 2021-04-07 06:37:31,423   [Trainer-0] ( 0 , 0 ): loss:  0.421131 , violators_lhs:  0.801472 , violators_rhs:  0.802969 , count:  24052
# 2021-04-07 06:37:31,425   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:31,429   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:31,432   [Trainer-0] Finished epoch 17 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:31,456   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:31,475   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:31,488   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:31,493   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:31,511   [Trainer-0] Starting epoch 18 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:31,517   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:31,519   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:31,524   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:31,527   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:31,982   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.44 s ( 0.055 M/sec ); io: 0.02 s ( 34.55 MB/sec )
# 2021-04-07 06:37:31,984   [Trainer-0] ( 0 , 0 ): loss:  0.41994 , violators_lhs:  0.795152 , violators_rhs:  0.787336 , count:  24052
# 2021-04-07 06:37:31,986   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:31,989   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:31,991   [Trainer-0] Finished epoch 18 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:32,020   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:32,179   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:32,196   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:32,198   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:32,218   [Trainer-0] Starting epoch 19 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:32,226   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:32,227   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:32,232   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:32,234   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:32,672   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.42 s ( 0.057 M/sec ); io: 0.02 s ( 28.25 MB/sec )
# 2021-04-07 06:37:32,674   [Trainer-0] ( 0 , 0 ): loss:  0.414156 , violators_lhs:  0.782721 , violators_rhs:  0.796483 , count:  24052
# 2021-04-07 06:37:32,676   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:32,679   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:32,683   [Trainer-0] Finished epoch 19 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:32,706   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:32,723   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:32,735   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:32,739   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:32,756   [Trainer-0] Starting epoch 20 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:32,761   [Trainer-0] Edge path: data/train_partitioned
# 2021-04-07 06:37:32,763   [Trainer-0] still in queue: 0
# 2021-04-07 06:37:32,768   [Trainer-0] Swapping partitioned embeddings None ( 0 , 0 )
# 2021-04-07 06:37:32,771   [Trainer-0] ( 0 , 0 ): Loading entities
# 2021-04-07 06:37:33,233   [Trainer-0] ( 0 , 0 ): bucket 1 / 1 : Processed 24052 edges in 0.44 s ( 0.054 M/sec ); io: 0.02 s ( 28.31 MB/sec )
# 2021-04-07 06:37:33,235   [Trainer-0] ( 0 , 0 ): loss:  0.412959 , violators_lhs:  0.78322 , violators_rhs:  0.791992 , count:  24052
# 2021-04-07 06:37:33,242   [Trainer-0] Swapping partitioned embeddings ( 0 , 0 ) None
# 2021-04-07 06:37:33,243   [Trainer-0] Writing partitioned embeddings
# 2021-04-07 06:37:33,244   [Trainer-0] Finished epoch 20 / 20, edge path 1 / 1, edge chunk 1 / 1
# 2021-04-07 06:37:33,273   [Trainer-0] Writing the metadata
# 2021-04-07 06:37:33,285   [Trainer-0] Writing the training stats
# 2021-04-07 06:37:33,306   [Trainer-0] Writing the checkpoint
# 2021-04-07 06:37:33,310   [Trainer-0] Switching to the new checkpoint version
# 2021-04-07 06:37:33,549   [Trainer-0] Exiting
# 2021-04-07 06:37:33,613   [Evaluator] Starting edge path 1 / 1 (data/test_partitioned)
# 2021-04-07 06:37:35,528   [Evaluator] ( 0 , 0 ): Processed 8018 edges in 1.9 s (0.0043M/sec); load time: 0.045 s
# 2021-04-07 06:37:35,532   [Evaluator] Stats for edge path 1 / 1, bucket ( 0 , 0 ): pos_rank:  4.44662 , mrr:  0.642094 , r1:  0.489898 , r10:  0.929346 , r50:  0.984161 , auc:  0.968758 , count:  8018
# 2021-04-07 06:37:35,536   [Evaluator]
# 2021-04-07 06:37:35,537   [Evaluator] Stats for edge path 1 / 1: pos_rank:  4.44662 , mrr:  0.642094 , r1:  0.489898 , r10:  0.929346 , r50:  0.984161 , auc:  0.968758 , count:  8018
# 2021-04-07 06:37:35,539   [Evaluator]
# 2021-04-07 06:37:35,541   [Evaluator]
# 2021-04-07 06:37:35,542   [Evaluator] Stats: pos_rank:  4.44662 , mrr:  0.642094 , r1:  0.489898 , r10:  0.929346 , r50:  0.984161 , auc:  0.968758 , count:  8018
# 2021-04-07 06:37:35,544   [Evaluator]

# %% [markdown]
# #Test

# %%
import json
import os
import h5py
import torch
from torchbiggraph.model import ComplexDiagonalDynamicOperator, DotComparator

with open("./data/statml/entity_names_user_id_0.json", "rt") as tf:
    dictionary = json.load(tf)

print(dictionary)
count = 0
def perform_prediction(source_id, target_id):
  try:
    offset_source = dictionary.index(source_id)
    #print("our offset for source_id " , source_id, " is: ", offset_source)
    offset_target = dictionary.index(target_id)
    #print("our offset for target_id " , target_id, " is: ", offset_target)
        
    with h5py.File("./model/statml_ranking_50_epochs_full_eval/embeddings_user_id_0.v20.h5", "r") as hf:
        embedding_source = hf["embeddings"][offset_source, :]
        embedding_target = hf["embeddings"][offset_target, :]


    comparator = DotComparator()
    comparator = DotComparator()
    score, _, _= comparator(
        comparator.prepare(torch.tensor(embedding_source.reshape([1,1,1024]))),
        comparator.prepare(torch.tensor(embedding_target.reshape([1,1,1024]))),
        torch.empty(1,0,1024),
        torch.empty(1,0,1024),
    )
    return score
  except:
    return 0.0
# Out:
# ['3182', '117', '56', '1779', '629', '993', '461', '2837', '2900', '261', '2133', '3492', '201', '1306', '2783', '3691', '2753', '2110', '3862', '2049', '3031', '692', '3277', '3114', '1330', '958', '1794', '224', '3698', '2252', '2733', '245', '1021', '716', '372', '355', '2951', '431', '203', '4080', '1052', '1020', '3624', '1009', '792', '2939', '1', '3281', '1449', '1913', '320', '3547', '2927', '98', '906', '2439', '2157', '2907', '2574', '1661', '2854', '2852', '251', '2112', '3863', '1397', '813', '1284', '1795', '228', '2051', '470', '279', '3506', '1062', '1347', '3666', '3064', '1073', '890', '3815', '1041', '3054', '708', '4044', '3453', '2798', '2443', '2037', '2247', '1814', '1487', '2018', '4036', '3056', '753', '1067', '3069', '1260', '522', '4021', '1947', '2200', '101', '2570', '3581', '1629', '859', '3824', '1558', '3493', '23', '408', '3077', '353', '105', '1016', '2763', '1139', '742', '3582', '3967', '2150', '3386', '1454', '2933', '212', '4058', '3755', '2681', '3712', '1258', '2918', '3516', '3104', '2832', '3294', '1191', '2306', '1916', '1384', '1994', '3917', '609', '130', '3609', '3956', '3767', '262', '3559', '2238', '315', '2457', '755', '2659', '2982', '45', '2937', '1691', '3785', '1763', '1755', '795', '3644', '3265', '2068', '1372', '3817', '379', '1311', '3829', '3675', '790', '204', '3461', '54', '1931', '1915', '2106', '3809', '4023', '1778', '1647', '293', '33', '2131', '3103', '1072', '686', '662', '403', '3446', '3377', '2171', '3704', '1623', '3053', '3968', '3784', '2993', '1637', '327', '3935', '3965', '3044', '2172', '1501', '3106', '1096', '2539', '3137', '3019', '858', '1714', '263', '2754', '2835', '4090', '927', '3895', '2899', '521', '2483', '3230', '1393', '719', '3571', '1248', '2675', '2264', '3184', '1764', '3853', '3586', '3295', '3710', '652', '106', '1886', '1645', '3080', '787', '398', '3563', '2199', '3001', '4092', '1342', '3199', '2605', '4085', '194', '2149', '1881', '617', '151', '1900', '110', '3525', '2670', '2978', '1068', '209', '3847', '3836', '3321', '669', '2210', '1974', '1086', '928', '1914', '4057', '2666', '1606', '600', '612', '3976', '1172', '1038', '162', '4030', '3513', '1039', '1154', '3529', '3202', '2315', '2830', '1975', '1628', '870', '1050', '3059', '269', '1507', '3093', '1925', '804', '2647', '264', '3607', '454', '566', '1618', '3807', '3232', '2059', '435', '3842', '3020', '2196', '1955', '3705', '1523', '3015', '1179', '2230', '1045', '860', '51', '1325', '2677', '752', '1274', '3316', '1295', '873', '3717', '2715', '1829', '445', '3391', '2974', '1100', '911', '2280', '2222', '289', '1873', '3341', '512', '2919', '3864', '1251', '3373', '2685', '1064', '1165', '799', '2345', '2185', '517', '1713', '2223', '1631', '2916', '2207', '3591', '735', '3087', '178', '4031', '1431', '3993', '601', '376', '2144', '413', '2184', '2914', '618', '2269', '2487', '4012', '3322', '838', '1670', '2476', '1453', '3854', '2786', '2686', '3963', '4063', '18', '1625', '3669', '2295', '2270', '2792', '1059', '3964', '1888', '1478', '1162', '2662', '1396', '1858', '3212', '1822', '3700', '2124', '1057', '622', '2868', '287', '1953', '3076', '1825', '4015', '113', '3344', '3363', '2949', '4084', '47', '1327', '1586', '2111', '885', '2161', '1106', '1132', '3560', '537', '1810', '2087', '286', '2932', '920', '3335', '2802', '738', '2936', '3151', '290', '2727', '493', '3699', '3411', '3250', '434', '3120', '1921', '274', '527', '855', '754', '1018', '3528', '740', '621', '183', '2324', '2466', '2667', '3972', '1948', '3544', '3908', '2506', '2722', '2335', '2637', '1379', '1048', '1245', '1450', '2865', '2386', '1153', '1538', '189', '3123', '3540', '501', '1980', '3282', '2887', '1404', '1044', '1392', '333', '761', '2616', '2775', '3943', '3436', '3749', '337', '3308', '221', '1769', '593', '2901', '3774', '1785', '1666', '720', '3631', '2364', '647', '1358', '1866', '702', '2333', '2271', '2532', '2120', '2163', '3017', '1526', '1677', '2272', '970', '750', '229 ...

# %%
# generate test samples:
test_samples = []
with open('data/test-public.csv', 'r') as f:
    next(f)
    for line in f:
        _, h, t = line.split(',')
        t = t[:len(t)-1]
        test_samples.append((h, t))

# %%
import numpy as np
def sigmoid(x):
    """ Sigmoid activation function
    :param x: scalar value
    :return: sigmoid activation
    """
    return 1 / (1 + np.exp(-x))
y_pred = []

n = len(test_samples)
i = 0
for i in range(0, n):
    sample = test_samples[i]
    #print(sample)
    pred = perform_prediction(str(sample[0]), str(sample[1]))
    #pred = pred.item()
    y_pred.append(pred)
    #print(pred)
    
    i += 1

proba = []
for element in y_pred:
    prob = sigmoid(element)
    proba.append(prob)

# %%
print(proba[:100])

print(proba[10])
final_res = []
for i in range(len(proba)):
    if proba[i] == 0.5:
        final_res.append(0.5)
        continue
    sz_test= proba[i][0][0].tolist()
    final_res.append(sz_test)

print(final_res)
# Out:
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# 0.5
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, ...

# %%
import csv
with open("DCN_2nd.csv","w",newline="") as csvfile:
    writer=csv.writer(csvfile)
    writer.writerow(["Id","Predicted"])
    test_id=1
    for prediction in final_res:
        writer.writerow([test_id,prediction])
        test_id+=1
